# %%
import pandas as pd

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.head()
# Out:
#    Unnamed: 0              Series_Title               Genre  \
# 0           0  The Shawshank Redemption               drama
# 1           1             The Godfather         crime drama
# 2           2           The Dark Knight  action crime drama
# 3           3    The Godfather: Part II         crime drama
# 4           4              12 Angry Men         crime drama
#
#                                             Overview             Director  \
# 0  imprison men bond number year find solac event...       frank darabont
# 1  organ crime dynasti age patriarch transfer con...  franci ford coppola
# 2  menac known joker wreak havoc chao peopl gotha...      christoph nolan
# 3  earli life career vito corleon s new york citi...  franci ford coppola
# 4  juri holdout attempt prevent miscarriag justic...         sidney lumet
#
#                                                Stars
# 0  tim robbin morgan freeman bob gunton william s...
# 1      marlon brando al pacino jame caan dian keaton
# 2  christian bale heath ledger aaron eckhart mich...
# 3     al pacino robert niro robert duval dian keaton
# 4  henri fonda lee j cobb martin balsam john fiedler

# %%
movies = movies.drop(columns = ["Unnamed: 0"])

# %%
movies.head()
# Out:
#                Series_Title               Genre  \
# 0  The Shawshank Redemption               drama
# 1             The Godfather         crime drama
# 2           The Dark Knight  action crime drama
# 3    The Godfather: Part II         crime drama
# 4              12 Angry Men         crime drama
#
#                                             Overview             Director  \
# 0  imprison men bond number year find solac event...       frank darabont
# 1  organ crime dynasti age patriarch transfer con...  franci ford coppola
# 2  menac known joker wreak havoc chao peopl gotha...      christoph nolan
# 3  earli life career vito corleon s new york citi...  franci ford coppola
# 4  juri holdout attempt prevent miscarriag justic...         sidney lumet
#
#                                                Stars
# 0  tim robbin morgan freeman bob gunton william s...
# 1      marlon brando al pacino jame caan dian keaton
# 2  christian bale heath ledger aaron eckhart mich...
# 3     al pacino robert niro robert duval dian keaton
# 4  henri fonda lee j cobb martin balsam john fiedler

# %%
movies['Movie_Info']= movies['Genre'] + ' ' +  movies['Overview']  + ' ' + movies['Director']  + ' ' + movies['Stars']

# %%
movies.head()
# Out:
#                Series_Title               Genre  \
# 0  The Shawshank Redemption               drama
# 1             The Godfather         crime drama
# 2           The Dark Knight  action crime drama
# 3    The Godfather: Part II         crime drama
# 4              12 Angry Men         crime drama
#
#                                             Overview             Director  \
# 0  imprison men bond number year find solac event...       frank darabont
# 1  organ crime dynasti age patriarch transfer con...  franci ford coppola
# 2  menac known joker wreak havoc chao peopl gotha...      christoph nolan
# 3  earli life career vito corleon s new york citi...  franci ford coppola
# 4  juri holdout attempt prevent miscarriag justic...         sidney lumet
#
#                                                Stars  \
# 0  tim robbin morgan freeman bob gunton william s...
# 1      marlon brando al pacino jame caan dian keaton
# 2  christian bale heath ledger aaron eckhart mich...
# 3     al pacino robert niro robert duval dian keaton
# 4  henri fonda lee j cobb martin balsam john fiedler
#
#                                           Movie_Info
# 0  drama imprison men bond number year find solac...
# 1  crime drama organ crime dynasti age patriarch ...
# 2  action crime drama menac known joker wreak hav...
# 3  crime drama earli life career vito corleon s n...
# 4  crime drama juri holdout attempt prevent misca...

# %%
movies = movies.drop(columns = ['Genre', 'Overview','Director','Stars'])

# %%
movies
# Out:
#                  Series_Title  \
# 0    The Shawshank Redemption
# 1               The Godfather
# 2             The Dark Knight
# 3      The Godfather: Part II
# 4                12 Angry Men
# ..                        ...
# 995    Breakfast at Tiffany's
# 996                     Giant
# 997     From Here to Eternity
# 998                  Lifeboat
# 999              The 39 Steps
#
#                                             Movie_Info
# 0    drama imprison men bond number year find solac...
# 1    crime drama organ crime dynasti age patriarch ...
# 2    action crime drama menac known joker wreak hav...
# 3    crime drama earli life career vito corleon s n...
# 4    crime drama juri holdout attempt prevent misca...
# ..                                                 ...
# 995  comedi drama romanc young new york socialit in...
# 996  drama western sprawl epic cover life texa catt...
# 997  drama romanc war hawaii privat cruelli punish ...
# 998  drama war survivor torpedo merchant ship world...
# 999  crime mysteri thriller man london tri help cou...
#
# [1000 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features=1000, stop_words='english')

# %%
cv
# Out:
# CountVectorizer(max_features=1000, stop_words='english')

# %%
vector= cv.fit_transform(movies['Movie_Info'].values.astype('U')).toarray()

# %%
vector.shape
# Out:
# (1000, 1000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_sim = cosine_similarity(vector,vector)

# %%
cosine_sim
# Out:
# array([[1.        , 0.06933752, 0.07692308, ..., 0.08006408, 0.14322297,
#         0.        ],
#        [0.06933752, 1.        , 0.20801257, ..., 0.07216878, 0.06454972,
#         0.08838835],
#        [0.07692308, 0.20801257, 1.        , ..., 0.08006408, 0.07161149,
#         0.04902903],
#        ...,
#        [0.08006408, 0.07216878, 0.08006408, ..., 1.        , 0.2236068 ,
#         0.        ],
#        [0.14322297, 0.06454972, 0.07161149, ..., 0.2236068 , 1.        ,
#         0.09128709],
#        [0.        , 0.08838835, 0.04902903, ..., 0.        , 0.09128709,
#         1.        ]])

# %%
cosine_sim_df = pd.DataFrame(cosine_sim, index=movies['Series_Title'], columns=movies['Series_Title'])
print(cosine_sim_df)
# Out:
# Series_Title              The Shawshank Redemption  The Godfather  \
# Series_Title
# The Shawshank Redemption                  1.000000       0.069338
# The Godfather                             0.069338       1.000000
# The Dark Knight                           0.076923       0.208013
# The Godfather: Part II                    0.053376       0.625463
# 12 Angry Men                              0.083624       0.226134
# ...                                            ...            ...
# Breakfast at Tiffany's                    0.062017       0.055902
# Giant                                     0.080064       0.144338
# From Here to Eternity                     0.080064       0.072169
# Lifeboat                                  0.143223       0.064550
# The 39 Steps                              0.000000       0.088388
#
# Series_Title              The Dark Knight  The Godfather: Part II  \
# Series_Title
# The Shawshank Redemption         0.076923                0.053376
# The Godfather                    0.208013                0.625463
# The Dark Knight                  1.000000                0.213504
# The Godfather: Part II           0.213504                1.000000
# 12 Angry Men                     0.167248                0.174078
# ...                                   ...                     ...
# Breakfast at Tiffany's           0.062017                0.129099
# Giant                            0.080064                0.166667
# From Here to Eternity            0.080064                0.055556
# Lifeboat                         0.071611                0.049690
# The 39 Steps                     0.049029                0.136083
#
# Series_Title              12 Angry Men  \
# Series_Title
# The Shawshank Redemption      0.083624
# The Godfather                 0.226134
# The Dark Knight               0.167248
# The Godfather: Part II        0.174078
# 12 Angry Men                  1.000000
# ...                                ...
# Breakfast at Tiffany's        0.067420
# Giant                         0.087039
# From Here to Eternity         0.087039
# Lifeboat                      0.155700
# The 39 Steps                  0.053300
#
# Series_Title              The Lord of the Rings: The Return of the King  \
# Series_Title
# The Shawshank Redemption                                       0.134535
# The Godfather                                                  0.060634
# The Dark Knight                                                0.134535
# The Godfather: Part II                                         0.046676
# 12 Angry Men                                                   0.073127
# ...                                                                 ...
# Breakfast at Tiffany's                                         0.054233
# Giant                                                          0.070014
# From Here to Eternity                                          0.070014
# Lifeboat                                                       0.125245
# The 39 Steps                                                   0.042875
#
# Series_Title              Pulp Fiction  Schindler's List  Inception  \
# Series_Title
# The Shawshank Redemption      0.127257          0.074125   0.000000
# The Godfather                 0.172062          0.066815   0.000000
# The Dark Knight               0.127257          0.074125   0.222375
# The Godfather: Part II        0.132453          0.051434   0.000000
# 12 Angry Men                  0.207514          0.080582   0.000000
# ...                                ...               ...        ...
# Breakfast at Tiffany's        0.051299          0.059761   0.000000
# Giant                         0.066227          0.154303   0.000000
# From Here to Eternity         0.132453          0.154303   0.000000
# Lifeboat                      0.118470          0.345033   0.000000
# The 39 Steps                  0.040555          0.000000   0.094491
#
# Series_Title              Fight Club  ...  Giù la testa  Kelly's Heroes  \
# Series_Title                          ...
# The Shawshank Redemption    0.083624  ...      0.076923        0.000000
# The Godfather               0.075378  ...      0.138675        0.000000
# The Dark Knight             0.167248  ...      0.076923        0.000000
# The Godfather: Part II      0.058026  ...      0.053376        0.000000
# 12 Angry Men                0.090909  ...      0.083624        0.000000
# ...                              ...  ...           ...             ...
# Breakfast at Tiffany's      0.134840  ...      0.062017        0.055902
# Giant                       0.087039  ...      0.240192        0.072169
# From Here to Eternity       0.087039  ...      0.160128        0.072169
# Lifeboat                    0.077850  ...      0.214834        0.129099
# The 39 Steps                0.000000  ...      0.000000        0.088388
#
# Series_Title              The Jungle Book    Blowup  A Hard Day's Night  \
# Series_Title
# The Shawshank Redemption         0.000000  0.071611            0.000000
# The Godfather                    0.000000  0.064550            0.000000
# The Dark Knight                  0.000000  0.071611            0.000000
# The Godfather: Part II           0.051434  0.049690            0.043033
# 12 Angry Men                     0.000000  0.155700            0.067420
# ...                                   ...       ...                 ...
# Breakfast at Tiffany's           0.000000  0.057735            0.100000
# Giant                            0.077152  0.074536            0.129099
# From Here to Eternity            0.000000  0.074536            0.000000
# Lifeboat                         0.000000  0.133333            0.057735
# The 39 Steps                     0.094491  0.091287            0.000000
#
# Series_Title              Breakfast at Tiffany's     Giant  \
# Series_Title
# The Shawshank Redemption                0.062017  0.080064
# The Godfather                           0.055902  0.144338
# The Dark Knight                         0.062017  0.080064
# The Godfather: Part II                  0.129099  0.166667
# 12 Angry Men                            0.067420  0.087039
# ...                                          ...       ...
# Breakfast at Tiffany's                  1.000000  0.129099
# Giant                                   0.129099  1.000000
# From Here to Eternity                   0.129099  0.083333
# Lifeboat                                0.057735  0.074536
# The 39 Steps                            0.079057  0.051031
#
# Series_Title              From Here to Eternity  Lifeboat  The 39 Steps
# Series_Title
# The Shawshank Redemption               0.080064  0.143223      0.000000
# The Godfather                          0.072169  0.064550      0.088388
# The Dark Knight                        0.080064  0.071611      0.049029
# The Godfather: Part II                 0.055556  0.049690      0.136083
# 12 Angry Men                           0.087039  0.155700      0.053300
# ...                                         ...       ...           ...
# Breakfast at Tiffany's                 0.129099  0.057735      0.079057
# Giant                                  0.083333  0.074536      0.051031
# From Here to Eternity                  1.000000  0.223607      0.000000
# Lifeboat                               0.223607  1.000000      0.091287
# The 39 Steps                           0.000000  0.091287      1.000000
#
# [1000 rows x 1000 columns]

# %%
movies[movies['Series_Title']== "The Godfather"].index[0]
# Out:
# 1

# %%
distance = sorted(list(enumerate(cosine_sim[1])),reverse=True, key=lambda vector: vector[1])
for i in distance[0:10]:
    print(movies.iloc[i[0]].Series_Title)
# Out:
# The Godfather
# The Godfather: Part III
# The Godfather: Part II
# Glengarry Glen Ross
# Scarface
# Capharnaüm
# Du rififi chez les hommes
# Rope
# Do lok tin si
# Dom za vesanje

# %%
def recommendMovie(movie_title, cosine_sim):
    # Check if the movie exists in the DataFrame
    if movie_title not in movies['Series_Title'].values:
        print(f"Movie '{movie_title}' not found in the database.")
        return

    # Find the index of the movie that matches the title
    index = movies[movies['Series_Title'] == movie_title].index[0]
    distance = sorted(list(enumerate(cosine_sim[index])), reverse=True, key=lambda vector: vector[1])
    
    # Print the top 10 most similar movies
    print(f"Top 10 movies similar to '{movie_title}':")
    for i in distance[0:10]: 
        print(movies.iloc[i[0]]['Series_Title'])

recommendMovie("The Godfather", cosine_sim)
# Out:
# Top 10 movies similar to 'The Godfather':
# The Godfather
# The Godfather: Part III
# The Godfather: Part II
# Glengarry Glen Ross
# Scarface
# Capharnaüm
# Du rififi chez les hommes
# Rope
# Do lok tin si
# Dom za vesanje

# %%
import time
def recommendMovie(movie_title, cosine_sim):
    # Check if the movie exists in the DataFrame
    if movie_title not in movies['Series_Title'].values:
        print(f"Movie '{movie_title}' not found in the database.")
        return []

    # Find the index of the movie that matches the title
    index = movies[movies['Series_Title'] == movie_title].index[0]
    distance = sorted(list(enumerate(cosine_sim[index])), reverse=True, key=lambda vector: vector[1])

    # Get the top 10 most similar movies
    recommended_movies = [movies.iloc[i[0]]['Series_Title'] 
    for i in distance[0:10]]

    return recommended_movies

# Get user input
user_movie = input("Enter a movie name: ")

start_time = time.time()


# Display the recommended movies
recommended_movies = recommendMovie(user_movie, cosine_sim)
print(f"Top 10 movies similar to '{user_movie}':")
for movie in recommended_movies:
    print(movie)

end_time = time.time()

# Evaluate performance
same_series = movies[movies["Series_Title"].str.contains(user_movie, case=False, na=False)]

# Accuracy: the fraction of relevant recommendations
def accuracy_at_k(y_true, y_pred, k):
    relevant = len(set(y_true) & set(y_pred[:k]))
    return relevant / len(y_true)

# Precision: measures how many of the top recommended items are relevant
def precision_at_k(y_true, y_pred, k):
    relevant = len(set(y_true) & set(y_pred[:k]))  # Intersection of ground truth and predicted
    return relevant / k

# Recall: measures how many relevant items are captured in the top recommendation
def recall_at_k(y_true, y_pred, k):
    relevant = len(set(y_true) & set(y_pred[:k]))
    return relevant / len(y_true)

# Harmonic mean of precision and recall
def f1_at_k(y_true, y_pred, k):
    prec = precision_at_k(y_true, y_pred, k)
    rec = recall_at_k(y_true, y_pred, k)
    if prec + rec == 0:
        return 0
    return 2 * (prec * rec) / (prec + rec)



# Actual movie titles that are considered similar (ground truth)
y_true = same_series["Series_Title"].tolist()

# Predicted movie titles from the recommendation
y_pred = recommended_movies

k = 10
accuracy = accuracy_at_k(y_true, y_pred, k)
precision = precision_at_k(y_true, y_pred, k)
recall = recall_at_k(y_true, y_pred, k)
f1 = f1_at_k(y_true, y_pred, k)

print(f"Accuracy@{k}: {accuracy:.2f}")
print(f"Precision@{k}: {precision:.2f}") 
print(f"Recall@{k}: {recall:.2f}")
print(f"F1@{k}: {f1:.2f}")
print(f"Executed Time: {end_time-start_time:.4f} seconds")
# Out:
# Enter a movie name:  The Godfather
# Top 10 movies similar to 'The Godfather':
# The Godfather
# The Godfather: Part III
# The Godfather: Part II
# Glengarry Glen Ross
# Scarface
# Capharnaüm
# Du rififi chez les hommes
# Rope
# Do lok tin si
# Dom za vesanje
# Accuracy@10: 1.00
# Precision@10: 0.30
# Recall@10: 1.00
# F1@10: 0.46
# Executed Time: 0.0016 seconds
